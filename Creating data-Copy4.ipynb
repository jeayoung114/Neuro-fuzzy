# %%
import numpy as np
import pandas as pd
import math
from math import exp
from sklearn.preprocessing import normalize
import matplotlib
import matplotlib.pyplot as plt

# %%
##HR graph
HR1=[-x for x in range(0,10000)]  ##0~10초
HR2=[HR1[9999]-3*x for x in range(0,15000)] ##10~25초
HR3=[HR2[14999]+5*x for x in range(0,20000)] ##25~45초
HR4=[HR3[19999]-x for x in range(0,38000)] ##45~83초
HR5=[HR4[37999]+3 for x in range(0,17000)] ##83~100초
HR6=[HR5[16999]+2 for x in range(0,20000)] ##100~120초
HR=[]
HR.extend(HR1)
HR.extend(HR2)
HR.extend(HR3)
HR.extend(HR4)
HR.extend(HR5)
HR.extend(HR6)
print(len(HR))
HR=np.array(HR)
print(np.shape(HR))
A=max(HR)-min(HR)

HR_1=[x/(2*A)+1 for x in HR]

fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot(1,1,1)
ax.set_ylim([0.5, 1.5])
xs = np.array([x for x in range(0,120000)])
ys = HR_1


plt.axvline(x=10000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=25000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=45000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=83000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=100000, color='r', linestyle='--', linewidth=0.5)

plt.plot(xs, ys)
plt.title('HR graph')
plt.show()
hr=np.array(HR_1)
print(hr)
# Out:
# 120000
# (120000,)
# [1.         0.999995   0.99999    ... 1.03502675 1.03502675 1.03502675]

# %%
##HP graph
HR1=[-3*x for x in range(0,10000)] ##0~10초
HR2=[HR1[9999]-2*x for x in range(0,15000)] ##10~25초
HR3=[HR2[14999]+4*x for x in range(0,20000)] ##25~45초
HR4=[HR3[19999]-6*x for x in range(0,38000)] ##45~83초
HR5=[HR4[37999]+8*x for x in range(0,17000)]##83~100초
HR6=[HR5[16999]+3*x for x in range(0,20000)] ##100~120초
HR=[]
HR.extend(HR1)
HR.extend(HR2)
HR.extend(HR3)
HR.extend(HR4)
HR.extend(HR5)
HR.extend(HR6)
print(len(HR))
HR=np.array(HR)
print(np.shape(HR))
A=max(HR)-min(HR)

HP=[x/(2*A)+1 for x in HR]

fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot(1,1,1)
ax.set_ylim([0.5, 1.5])
xs = np.array([x for x in range(0,120000)])
ys = HP


plt.axvline(x=10000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=25000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=45000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=83000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=100000, color='r', linestyle='--', linewidth=0.5)

plt.plot(xs, ys)
plt.title('HP graph')
plt.show()
# Out:
# 120000
# (120000,)

# %%
##RR graph
HR1=[-8*x for x in range(0,10000)] ##0~10초
HR2=[HR1[9999]-7*x for x in range(0,15000)] ##10~25초
HR3=[HR2[14999]+(13*x) for x in range(0,20000)] ##25~45초
HR4=[HR3[19999]-3*x for x in range(0,38000)] ##45~83초
HR5=[HR4[37999]+10*x for x in range(0,17000)]##83~100초
HR6=[HR5[16999]+7*x for x in range(0,20000)] ##100~120초
HR=[]
HR.extend(HR1)
HR.extend(HR2)
HR.extend(HR3)
HR.extend(HR4)
HR.extend(HR5)
HR.extend(HR6)
print(len(HR))
HR=np.array(HR)
print(np.shape(HR))
A=max(HR)-min(HR)

RR=[x/(2*A)+1 for x in HR]

fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot(1,1,1)
ax.set_ylim([0.5, 1.5])
xs = np.array([x for x in range(0,120000)])
ys = RR


plt.axvline(x=10000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=25000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=45000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=83000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=100000, color='r', linestyle='--', linewidth=0.5)

plt.plot(xs, ys)
plt.title('RR graph')
plt.show()
# Out:
# 120000
# (120000,)

# %%
arr=np.array([hr,HP,RR])

np.shape(arr)
arr=pd.DataFrame(arr)
df=arr.T
df
# Out:
#                0         1         2
# 0       1.000000  1.000000  1.000000
# 1       0.999995  0.999993  0.999991
# 2       0.999990  0.999987  0.999982
# 3       0.999985  0.999980  0.999974
# 4       0.999980  0.999974  0.999965
# 5       0.999975  0.999967  0.999956
# 6       0.999970  0.999961  0.999947
# 7       0.999965  0.999954  0.999939
# 8       0.999960  0.999947  0.999930
# 9       0.999955  0.999941  0.999921
# 10      0.999950  0.999934  0.999912
# 11      0.999945  0.999928  0.999904
# 12      0.999940  0.999921  0.999895
# 13      0.999935  0.999914  0.999886
# 14      0.999930  0.999908  0.999877
# 15      0.999925  0.999901  0.999868
# 16      0.999920  0.999895  0.999860
# 17      0.999915  0.999888  0.999851
# 18      0.999910  0.999882  0.999842
# 19      0.999905  0.999875  0.999833
# 20      0.999900  0.999868  0.999825
# 21      0.999895  0.999862  0.999816
# 22      0.999890  0.999855  0.999807
# 23      0.999885  0.999849  0.999798
# 24      0.999880  0.999842  0.999789
# 25      0.999875  0.999836  0.999781
# 26      0.999870  0.999829  0.999772
# 27      0.999865  0.999822  0.999763
# 28      0.999860  0.999816  0.999754
# 29      0.999855  0.999809  0.999746
# ...          ...       ...       ...
# 119970  1.035027  0.973484  1.296931
# 119971  1.035027  0.973491  1.296939
# 119972  1.035027  0.973497  1.296946
# 119973  1.035027  0.973504  1.296954
# 119974  1.035027  0.973510  1.296962
# 119975  1.035027  0.973517  1.296969
# 119976  1.035027  0.973523  1.296977
# 119977  1.035027  0.973530  1.296985
# 119978  1.035027  0.973537  1.296992
# 119979  1.035027  0.973543  1.297000
# 119980  1.035027  0.973550  1.297008
# 119981  1.035027  0.973556  1.297015
# 119982  1.035027  0.973563  1.297023
# 119983  1.035027  0.973569  1.297031
# 119984  1.035027  0.973576  1.297038
# 119985  1.035027  0.973583  1.297046
# 119986  1.035027  0.973589  1.297054
# 119987  1.035027  0.973596  1.297061
# 119988  1.035027  0.973602  1.297069
# 119989  1.035027  0.973609  1.297077
# 119990  1.035027  0.973616  1.297084
# 119991  1.035027  0.973622  1.297092
# 119992  1.035027  0.973629  1.297100
# 119993  1.035027  0.973635  1.297108
# 119994  1.035027  0.973642  1.297115
# 119995  1.035027  0.973648  1.297123
# 119996  1.035027  0.973655  1.297131
# 119997  1.035027  0.973662  1.297138
# 119998  1.035027  0.973668  1.297146
# 119999  1.035027  0.973675  1.297154
#
# [120000 rows x 3 columns]

# %%
df.to_csv('fuzzy5(linear).csv')
