# %%
import numpy as np
import pandas as pd
import math
from math import exp
from sklearn.preprocessing import normalize
import matplotlib
import matplotlib.pyplot as plt

# %%
##HR graph
HR1=[-3*x for x in range(0,10000)]  ##0~10초
HR2=[HR1[9999]+x for x in range(0,15000)] ##10~25초
HR3=[HR2[14999]+3*x for x in range(0,20000)] ##25~45초
HR4=[HR3[19999]-x for x in range(0,38000)] ##45~83초
HR5=[HR4[37999]+4 for x in range(0,17000)] ##83~100초
HR6=[HR5[16999]-x for x in range(0,20000)] ##100~120초
HR=[]
HR.extend(HR1)
HR.extend(HR2)
HR.extend(HR3)
HR.extend(HR4)
HR.extend(HR5)
HR.extend(HR6)
print(len(HR))
HR=np.array(HR)
print(np.shape(HR))
A=max(HR)-min(HR)

HR_1=[x/(2*A)+1 for x in HR]

fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot(1,1,1)
ax.set_ylim([0.5, 1.5])
xs = np.array([x for x in range(0,120000)])
ys = HR_1


plt.axvline(x=10000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=25000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=45000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=83000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=100000, color='r', linestyle='--', linewidth=0.5)

plt.plot(xs, ys)
plt.title('HR graph')
plt.show()
hr=np.array(HR_1)
print(hr)
# Out:
# 120000
# (120000,)
# [1.         0.99998    0.99996    ... 0.91337538 0.91336871 0.91336205]

# %%
##HP graph
HR1=[-2*x for x in range(0,10000)] ##0~10초
HR2=[HR1[9999]+10*x for x in range(0,15000)] ##10~25초
HR3=[HR2[14999]+3*x for x in range(0,20000)] ##25~45초
HR4=[HR3[19999]-2*x for x in range(0,38000)] ##45~83초
HR5=[HR4[37999]+2*math.log(x+2)*x for x in range(0,17000)]##83~100초
HR6=[HR5[16999]-5*x for x in range(0,20000)] ##100~120초
HR=[]
HR.extend(HR1)
HR.extend(HR2)
HR.extend(HR3)
HR.extend(HR4)
HR.extend(HR5)
HR.extend(HR6)
print(len(HR))
HR=np.array(HR)
print(np.shape(HR))
A=max(HR)-min(HR)

HP=[x/(2*A)+1 for x in HR]

fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot(1,1,1)
ax.set_ylim([0.5, 1.5])
xs = np.array([x for x in range(0,120000)])
ys = HP


plt.axvline(x=10000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=25000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=45000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=83000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=100000, color='r', linestyle='--', linewidth=0.5)

plt.plot(xs, ys)
plt.title('HP graph')
plt.show()
# Out:
# 120000
# (120000,)

# %%
##RR graph
HR1=[-0.45*x for x in range(0,10000)] ##0~10초
HR2=[HR1[9999]+0.25*x for x in range(0,15000)] ##10~25초
HR3=[HR2[14999]+(2*x) for x in range(0,20000)] ##25~45초
HR4=[HR3[19999]-3*x for x in range(0,38000)] ##45~83초
HR5=[HR4[37999]+0.75*x for x in range(0,17000)]##83~100초
HR6=[HR5[16999]-0.2*x for x in range(0,20000)] ##100~120초
HR=[]
HR.extend(HR1)
HR.extend(HR2)
HR.extend(HR3)
HR.extend(HR4)
HR.extend(HR5)
HR.extend(HR6)
print(len(HR))
HR=np.array(HR)
print(np.shape(HR))
A=max(HR)-min(HR)

RR=[x/(2*A)+1 for x in HR]

fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot(1,1,1)
ax.set_ylim([0.5, 1.5])
xs = np.array([x for x in range(0,120000)])
ys = RR


plt.axvline(x=10000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=25000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=45000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=83000, color='r', linestyle='--', linewidth=0.5)
plt.axvline(x=100000, color='r', linestyle='--', linewidth=0.5)

plt.plot(xs, ys)
plt.title('RR graph')
plt.show()
# Out:
# 120000
# (120000,)

# %%
arr=np.array([hr,HP,RR])

np.shape(arr)
arr=pd.DataFrame(arr)
df=arr.T
df
# Out:
#                0         1         2
# 0       1.000000  1.000000  1.000000
# 1       0.999980  0.999998  0.999998
# 2       0.999960  0.999996  0.999996
# 3       0.999940  0.999994  0.999994
# 4       0.999920  0.999991  0.999992
# 5       0.999900  0.999989  0.999990
# 6       0.999880  0.999987  0.999988
# 7       0.999860  0.999985  0.999986
# 8       0.999840  0.999983  0.999984
# 9       0.999820  0.999981  0.999982
# 10      0.999800  0.999979  0.999980
# 11      0.999780  0.999976  0.999978
# 12      0.999760  0.999974  0.999976
# 13      0.999740  0.999972  0.999974
# 14      0.999720  0.999970  0.999972
# 15      0.999700  0.999968  0.999970
# 16      0.999680  0.999966  0.999968
# 17      0.999660  0.999963  0.999966
# 18      0.999640  0.999961  0.999964
# 19      0.999620  0.999959  0.999962
# 20      0.999600  0.999957  0.999961
# 21      0.999580  0.999955  0.999959
# 22      0.999560  0.999953  0.999957
# 23      0.999540  0.999951  0.999955
# 24      0.999520  0.999948  0.999953
# 25      0.999500  0.999946  0.999951
# 26      0.999480  0.999944  0.999949
# 27      0.999460  0.999942  0.999947
# 28      0.999440  0.999940  0.999945
# 29      0.999420  0.999938  0.999943
# ...          ...       ...       ...
# 119970  0.913555  1.371177  0.710547
# 119971  0.913549  1.371171  0.710546
# 119972  0.913542  1.371166  0.710545
# 119973  0.913535  1.371161  0.710544
# 119974  0.913529  1.371155  0.710543
# 119975  0.913522  1.371150  0.710543
# 119976  0.913515  1.371144  0.710542
# 119977  0.913509  1.371139  0.710541
# 119978  0.913502  1.371134  0.710540
# 119979  0.913495  1.371128  0.710539
# 119980  0.913489  1.371123  0.710538
# 119981  0.913482  1.371118  0.710537
# 119982  0.913475  1.371112  0.710536
# 119983  0.913469  1.371107  0.710536
# 119984  0.913462  1.371101  0.710535
# 119985  0.913455  1.371096  0.710534
# 119986  0.913449  1.371091  0.710533
# 119987  0.913442  1.371085  0.710532
# 119988  0.913435  1.371080  0.710531
# 119989  0.913429  1.371075  0.710530
# 119990  0.913422  1.371069  0.710529
# 119991  0.913415  1.371064  0.710529
# 119992  0.913409  1.371059  0.710528
# 119993  0.913402  1.371053  0.710527
# 119994  0.913395  1.371048  0.710526
# 119995  0.913389  1.371042  0.710525
# 119996  0.913382  1.371037  0.710524
# 119997  0.913375  1.371032  0.710523
# 119998  0.913369  1.371026  0.710522
# 119999  0.913362  1.371021  0.710522
#
# [120000 rows x 3 columns]

# %%
df.to_csv('fuzzy3(linear).csv')
